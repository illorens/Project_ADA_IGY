# %%
# Add your imports here
import pandas as pd
import numpy as np
import scipy as sp
import findspark
import os
findspark.init(os.environ['SPARK_HOME'])
from pyspark.sql import *
from pyspark.sql.functions import *
import matplotlib.pyplot as plt

# %%
departements = (["{:0^3}".format(i) for i in range(1, 20)] +
               ["{:0^3}".format(i) for i in range(21, 96)] +
               # Corsica
               ["2A0", "2B0"] +
               # DOM-TOM
               ["{}".format(i) for i in range(971, 975)] + ["976"])

# %%
# Read all the departments-related sheets of the excel files
# The headers are split across rows 19 and 20.
ircom_communes = pd.read_excel("../data/raw/ircom_2017_revenus_2016.xlsx", header=[19, 20],
                               sheet_name=departements
                              )

# %%
def format_sheet(sheet, sheet_name):
    ircom_communes_processed = sheet
    ircom_communes_processed.columns = ['_'.join([column for column in col if not "Unnamed" in column])
                                            .strip().strip('_') 
                                        for col in ircom_communes_processed.columns.values
                                        ]
    return ircom_communes_processed


ircom_communes_aggregated = None
for sheet_name, sheet in ircom_communes.items():
    if ircom_communes_aggregated is not None:
        df = format_sheet(sheet, sheet_name)
        ircom_communes_aggregated = pd.concat([ircom_communes_aggregated, df])
    else:
        ircom_communes_aggregated = format_sheet(sheet, sheet_name)

ircom_communes_aggregated.head()
# Out:
#     Dép.  Commune    Libellé de la commune  \
# NaN   10        1  L'Abergement-Clémenciat
# NaN   10        2    L'Abergement-de-Varey
# NaN   10        4        Ambérieu-en-Bugey
# NaN   10        4        Ambérieu-en-Bugey
# NaN   10        4        Ambérieu-en-Bugey
#
#     Revenu fiscal de référence par tranche (en euros)  \
# NaN                                             Total
# NaN                                             Total
# NaN                                        0 à 10 000
# NaN                                   10 001 à 12 000
# NaN                                   12 001 à 15 000
#
#     Nombre de foyers fiscaux Revenu fiscal de référence des foyers fiscaux  \
# NaN                      413                                         12210
# NaN                      127                                       3866.62
# NaN                     1754                                       7411.82
# NaN                      497                                       5476.77
# NaN                      894                                       12154.1
#
#     Impôt net (total)* Nombre de foyers fiscaux imposés  \
# NaN            692.389                              219
# NaN            196.849                               67
# NaN            -15.782                             n.c.
# NaN             -9.969                             n.c.
# NaN            -23.811                               58
#
#     Revenu fiscal de référence des foyers fiscaux imposés  \
# NaN                                            8917.02
# NaN                                            2776.44
# NaN                                               n.c.
# NaN                                               n.c.
# NaN                                             861.66
#
#     Traitements et salaires_Nombre de foyers concernés  \
# NaN                                                280
# NaN                                                 93
# NaN                                                849
# NaN                                                318
# NaN                                                693
#
#     Traitements et salaires_Montant  \
# NaN                         8769.07
# NaN                         2825.99
# NaN                         5426.35
# NaN                         4075.28
# NaN                         10835.4
#
#     Retraites et pensions_Nombre de foyers concernés  \
# NaN                                              155
# NaN                                               42
# NaN                                              467
# NaN                                              191
# NaN                                              227
#
#     Retraites et pensions_Montant
# NaN                       3802.81
# NaN                        1189.4
# NaN                        3989.3
# NaN                       2516.25
# NaN                       3352.28

# %%
ircom_communes_aggregated = ircom_communes_aggregated[
    ircom_communes_aggregated['Revenu fiscal de référence par tranche (en euros)'] == 'Total'
]
ircom_communes_aggregated = ircom_communes_aggregated.drop(columns=['Impôt net (total)*', 'Traitements et salaires_Nombre de foyers concernés',
       'Traitements et salaires_Montant',
       'Retraites et pensions_Nombre de foyers concernés',
       'Revenu fiscal de référence des foyers fiscaux imposés',
       'Revenu fiscal de référence par tranche (en euros)',
       'Retraites et pensions_Montant'])
ircom_communes_aggregated.head()
# Out:
#     Dép.  Commune    Libellé de la commune Nombre de foyers fiscaux  \
# NaN   10        1  L'Abergement-Clémenciat                      413
# NaN   10        2    L'Abergement-de-Varey                      127
# NaN   10        4        Ambérieu-en-Bugey                     8186
# NaN   10        5      Ambérieux-en-Dombes                      862
# NaN   10        6                  Ambléon                       59
#
#     Revenu fiscal de référence des foyers fiscaux  \
# NaN                                         12210
# NaN                                       3866.62
# NaN                                        194722
# NaN                                       25561.9
# NaN                                       1755.41
#
#     Nombre de foyers fiscaux imposés
# NaN                              219
# NaN                               67
# NaN                             3505
# NaN                              442
# NaN                               32

# %%
ircom_communes_aggregated = ircom_communes_aggregated[ircom_communes_aggregated['Nombre de foyers fiscaux'] != "n.c."]

# %%
ircom_communes_aggregated = ircom_communes_aggregated[ircom_communes_aggregated['Revenu fiscal de référence des foyers fiscaux'] != "n.c."]
ircom_communes_aggregated = ircom_communes_aggregated[ircom_communes_aggregated['Nombre de foyers fiscaux imposés'] != "n.c."]

# %%
ircom_communes_aggregated['Nombre de foyers fiscaux'] = ircom_communes_aggregated['Nombre de foyers fiscaux'].astype('int')
ircom_communes_aggregated['Revenu fiscal de référence des foyers fiscaux'] = ircom_communes_aggregated['Revenu fiscal de référence des foyers fiscaux'].astype('float')
ircom_communes_aggregated['Nombre de foyers fiscaux imposés'] = ircom_communes_aggregated['Nombre de foyers fiscaux imposés'].astype('int')

# %%
ircom_communes_aggregated['Mean reference fiscal income (in k€)'] = ircom_communes_aggregated["Revenu fiscal de référence des foyers fiscaux"] / ircom_communes_aggregated['Nombre de foyers fiscaux']

# %%
ircom_communes_aggregated.head()
# Out:
#     Dép.  Commune    Libellé de la commune  Nombre de foyers fiscaux  \
# NaN   10        1  L'Abergement-Clémenciat                       413
# NaN   10        2    L'Abergement-de-Varey                       127
# NaN   10        4        Ambérieu-en-Bugey                      8186
# NaN   10        5      Ambérieux-en-Dombes                       862
# NaN   10        6                  Ambléon                        59
#
#      Revenu fiscal de référence des foyers fiscaux  \
# NaN                                      12209.992
# NaN                                       3866.621
# NaN                                     194722.047
# NaN                                      25561.917
# NaN                                       1755.412
#
#      Nombre de foyers fiscaux imposés  Mean reference fiscal income (in k€)
# NaN                               219                             29.564145
# NaN                                67                             30.445835
# NaN                              3505                             23.787203
# NaN                               442                             29.654196
# NaN                                32                             29.752746

# %%
# Helper to remove the accents
import unicodedata as ud

def remove_accents(input_str):
    nkfd_form = ud.normalize('NFKD', str(input_str))
    return u"".join([c for c in nkfd_form if not ud.combining(c)])

# %%
global_arrond = pd.read_csv("../data/processed/clean_food_cities_arrond.csv")
global_arrond.head()
# Out:
#    Unnamed: 0  food_item_index  nutrition-score-fr_100g  \
# 0           0           362362                     15.0
# 1           1           362364                     15.0
# 2           2           362386                     15.0
# 3           3           362366                     14.0
# 4           4           362389                     14.0
#
#    nutrition-score-uk_100g  nutrition_grade_numeric serving_size  energy_100g  \
# 0                     20.0                        4          NaN       1402.0
# 1                     20.0                        4          NaN       1435.0
# 2                     20.0                        4          NaN       1435.0
# 3                     19.0                        4          NaN       1238.0
# 4                     19.0                        4        150 g       1243.0
#
#    fat_100g  saturated-fat_100g  proteins_100g  carbohydrates_100g  \
# 0      30.0                19.0           15.0                 1.3
# 1      31.0                21.0           15.0                 1.0
# 2      31.0                21.0           15.0                 1.0
# 3      24.0                18.0           19.0                 1.0
# 4      24.0                17.0           19.0                 1.3
#
#    sugars_100g  fiber_100g  Median revenue euros  Total poverty rate (%)  \
# 0          1.3         NaN               18563.0               18.618075
# 1          1.0         NaN               18563.0               18.618075
# 2          1.0         0.0               18563.0               18.618075
# 3          1.0         NaN               18563.0               18.618075
# 4          1.3         0.0               18563.0               18.618075
#
#    Poverty rate (-30) (%)  Poverty rate (30-39) (%)  Poverty rate (40-49) (%)  \
# 0                     NaN                 22.133096                 22.284813
# 1                     NaN                 22.133096                 22.284813
# 2                     NaN                 22.133096                 22.284813
# 3                     NaN                 22.133096                 22.284813
# 4                     NaN                 22.133096                 22.284813
#
#    Poverty rate (50-59) (%)  Poverty rate (60-74) (%)  Poverty rate (75+) (%)  \
# 0                 15.726548                 16.949153                     NaN
# 1                 15.726548                 16.949153                     NaN
# 2                 15.726548                 16.949153                     NaN
# 3                 15.726548                 16.949153                     NaN
# 4                 15.726548                 16.949153                     NaN
#
#    Poverty rate (house owners) (%)  Poverty rate (tenants) (%)  \
# 0                         6.205567                   29.609475
# 1                         6.205567                   29.609475
# 2                         6.205567                   29.609475
# 3                         6.205567                   29.609475
# 4                         6.205567                   29.609475
#
#    Share of activity revenue (%)  Share of retreat pension revenue (%)  \
# 0                           65.9                                  31.2
# 1                           65.9                                  31.2
# 2                           65.9                                  31.2
# 3                           65.9                                  31.2
# 4                           65.9                                  31.2
#
#    Share of heritage revenue and other (%)  \
# 0                                     11.1
# 1                                     11.1
# 2                                     11.1
# 3                                     11.1
# 4                                     11.1
#
#    Share of social benefits revenue (%)  Share of taxes (%) City name  \
# 0                                   7.1               -15.3    Belley
# 1                                   7.1               -15.3    Belley
# 2                                   7.1               -15.3    Belley
# 3                                   7.1               -15.3    Belley
# 4                                   7.1               -15.3    Belley
#
#   Department  Region custom_arrondissement_code city_name  \
# 0         01      84                      01001    belley
# 1         01      84                      01001    belley
# 2         01      84                      01001    belley
# 3         01      84                      01001    belley
# 4         01      84                      01001    belley
#
#   city_tag_from_food_item
# 0       belley-ain-france
# 1       belley-ain-france
# 2       belley-ain-france
# 3       belley-ain-france
# 4       belley-ain-france

# %%
global_arrond = global_arrond.drop(columns=['Unnamed: 0'])
global_arrond = global_arrond.drop_duplicates()

# %%
global_arrond['Department'] = ["{:0^3}".format(d) for d in global_arrond['Department']]

# %%
ircom_communes_aggregated['city_tag'] = ircom_communes_aggregated['Libellé de la commune'].apply(
    lambda x: remove_accents(x.lower().replace("'", "-"))
)
ircom_communes_aggregated.head()
# Out:
#     Dép.  Commune    Libellé de la commune  Nombre de foyers fiscaux  \
# NaN   10        1  L'Abergement-Clémenciat                       413
# NaN   10        2    L'Abergement-de-Varey                       127
# NaN   10        4        Ambérieu-en-Bugey                      8186
# NaN   10        5      Ambérieux-en-Dombes                       862
# NaN   10        6                  Ambléon                        59
#
#      Revenu fiscal de référence des foyers fiscaux  \
# NaN                                      12209.992
# NaN                                       3866.621
# NaN                                     194722.047
# NaN                                      25561.917
# NaN                                       1755.412
#
#      Nombre de foyers fiscaux imposés  Mean reference fiscal income (in k€)  \
# NaN                               219                             29.564145
# NaN                                67                             30.445835
# NaN                              3505                             23.787203
# NaN                               442                             29.654196
# NaN                                32                             29.752746
#
#                     city_tag
# NaN  l-abergement-clemenciat
# NaN    l-abergement-de-varey
# NaN        amberieu-en-bugey
# NaN      amberieux-en-dombes
# NaN                  ambleon

# %%
global_arrond = pd.merge(ircom_communes_aggregated, global_arrond, left_on=['city_tag', 'Dép.'], right_on=['city_name', 'Department'])

# %%
pd.set_option('display.max_columns', 50)
global_arrond.head()
# Out:
#   Dép.  Commune Libellé de la commune  Nombre de foyers fiscaux  \
# 0  2B0       58                Canari                       184
# 1  2B0       88               Chiatra                       145
# 2  2B0       88               Chiatra                       145
# 3  2B0      123           Ghisonaccia                      2190
# 4  2B0      167           Montegrosso                       268
#
#    Revenu fiscal de référence des foyers fiscaux  \
# 0                                       3017.682
# 1                                       3047.807
# 2                                       3047.807
# 3                                      47584.009
# 4                                       5397.784
#
#    Nombre de foyers fiscaux imposés  Mean reference fiscal income (in k€)  \
# 0                                49                             16.400446
# 1                                46                             21.019359
# 2                                46                             21.019359
# 3                               718                             21.727858
# 4                               101                             20.140985
#
#       city_tag  food_item_index  nutrition-score-fr_100g  \
# 0       canari           307386                     25.0
# 1      chiatra           485735                      4.0
# 2      chiatra           485732                      3.0
# 3  ghisonaccia           335427                     13.0
# 4  montegrosso           370573                     14.0
#
#    nutrition-score-uk_100g  nutrition_grade_numeric serving_size  energy_100g  \
# 0                     25.0                        5       31.2 g       2159.0
# 1                     -3.0                        3          NaN        192.0
# 2                     -3.0                        3          NaN        180.0
# 3                     18.0                        4          NaN       1833.0
# 4                     14.0                        4          NaN       2000.0
#
#    fat_100g  saturated-fat_100g  proteins_100g  carbohydrates_100g  \
# 0      27.0               18.00            5.2                64.0
# 1       0.0                0.00            0.0                11.0
# 2       0.0                0.00            0.0                10.0
# 3      38.5                8.40           24.0                 0.0
# 4      19.4                1.69            6.9                67.5
#
#    sugars_100g  fiber_100g  Median revenue euros  Total poverty rate (%)  \
# 0         23.0         0.0          14962.000000                     NaN
# 1         10.0         NaN          19395.555556                     NaN
# 2         10.0         0.0          19395.555556                     NaN
# 3          0.0         0.0          16595.500000               28.895753
# 4         28.8         NaN          18541.333333                     NaN
#
#    Poverty rate (-30) (%)  Poverty rate (30-39) (%)  Poverty rate (40-49) (%)  \
# 0                     NaN                       NaN                       NaN
# 1                     NaN                       NaN                       NaN
# 2                     NaN                       NaN                       NaN
# 3                     NaN                       NaN                 39.115411
# 4                     NaN                       NaN                       NaN
#
#    Poverty rate (50-59) (%)  Poverty rate (60-74) (%)  Poverty rate (75+) (%)  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
#
#    Poverty rate (house owners) (%)  Poverty rate (tenants) (%)  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                        13.776435                   44.707741
# 4                              NaN                         NaN
#
#    Share of activity revenue (%)  Share of retreat pension revenue (%)  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                           67.3                                  30.1
# 4                            NaN                                   NaN
#
#    Share of heritage revenue and other (%)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                     12.8
# 4                                      NaN
#
#    Share of social benefits revenue (%)  Share of taxes (%)    City name  \
# 0                                   NaN                 NaN       Canari
# 1                                   NaN                 NaN      Chiatra
# 2                                   NaN                 NaN      Chiatra
# 3                                   6.9               -17.1  Ghisonaccia
# 4                                   NaN                 NaN  Montegrosso
#
#   Department  Region custom_arrondissement_code    city_name  \
# 0        2B0      94                      2B002       canari
# 1        2B0      94                      2B003      chiatra
# 2        2B0      94                      2B003      chiatra
# 3        2B0      94                      2B003  ghisonaccia
# 4        2B0      94                      2B005  montegrosso
#
#     city_tag_from_food_item
# 0       canari-corse-france
# 1      chiatra-corse-france
# 2      chiatra-corse-france
# 3  ghisonaccia-corse-france
# 4  montegrosso-corse-france

# %%
global_arrond.drop(columns=["Dép.", "Commune", "Libellé de la commune", "Revenu fiscal de référence des foyers fiscaux"],
                   inplace=True)
global_arrond.rename(columns={"Nombre de foyers fiscaux": "Fiscal household number", 
                              "Nombre de foyers fiscaux imposés": "Taxed households number",
                             })
# Out:
#    Fiscal household number  Taxed households number  \
# 0                      184                       49
# 1                      145                       46
# 2                      145                       46
# 3                     2190                      718
# 4                      268                      101
# 5                      117                       58
# 6                      117                       58
# 7                      117                       58
# 8                      117                       58
#
#    Mean reference fiscal income (in k€)     city_tag  food_item_index  \
# 0                             16.400446       canari           307386
# 1                             21.019359      chiatra           485735
# 2                             21.019359      chiatra           485732
# 3                             21.727858  ghisonaccia           335427
# 4                             20.140985  montegrosso           370573
# 5                             26.911607       urtaca           393685
# 6                             26.911607       urtaca           335610
# 7                             26.911607       urtaca           420298
# 8                             26.911607       urtaca           335609
#
#    nutrition-score-fr_100g  nutrition-score-uk_100g  nutrition_grade_numeric  \
# 0                     25.0                     25.0                        5
# 1                      4.0                     -3.0                        3
# 2                      3.0                     -3.0                        3
# 3                     13.0                     18.0                        4
# 4                     14.0                     14.0                        4
# 5                     21.0                     21.0                        5
# 6                     15.0                     15.0                        4
# 7                     24.0                     24.0                        5
# 8                     21.0                     21.0                        5
#
#   serving_size  energy_100g  fat_100g  saturated-fat_100g  proteins_100g  \
# 0       31.2 g       2159.0      27.0               18.00            5.2
# 1          NaN        192.0       0.0                0.00            0.0
# 2          NaN        180.0       0.0                0.00            0.0
# 3          NaN       1833.0      38.5                8.40           24.0
# 4          NaN       2000.0      19.4                1.69            6.9
# 5          NaN       1218.0      20.1                8.20           26.0
# 6          NaN        933.0       9.4                3.80           33.7
# 7          NaN       1615.0      31.0               13.00           27.0
# 8          NaN       1211.0      20.1                8.20           26.3
#
#    carbohydrates_100g  sugars_100g  fiber_100g  Median revenue euros  \
# 0                64.0         23.0         0.0          14962.000000
# 1                11.0         10.0         NaN          19395.555556
# 2                10.0         10.0         0.0          19395.555556
# 3                 0.0          0.0         0.0          16595.500000
# 4                67.5         28.8         NaN          18541.333333
# 5                 1.1          0.5         0.0          20603.846154
# 6                 0.8          0.4         NaN          20603.846154
# 7                 1.0          0.0         NaN          20603.846154
# 8                 1.1          0.5         NaN          20603.846154
#
#    Total poverty rate (%)  Poverty rate (-30) (%)  Poverty rate (30-39) (%)  \
# 0                     NaN                     NaN                       NaN
# 1                     NaN                     NaN                       NaN
# 2                     NaN                     NaN                       NaN
# 3               28.895753                     NaN                       NaN
# 4                     NaN                     NaN                       NaN
# 5                     NaN                     NaN                       NaN
# 6                     NaN                     NaN                       NaN
# 7                     NaN                     NaN                       NaN
# 8                     NaN                     NaN                       NaN
#
#    Poverty rate (40-49) (%)  Poverty rate (50-59) (%)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                 39.115411                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
#
#    Poverty rate (60-74) (%)  Poverty rate (75+) (%)  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# 5                       NaN                     NaN
# 6                       NaN                     NaN
# 7                       NaN                     NaN
# 8                       NaN                     NaN
#
#    Poverty rate (house owners) (%)  Poverty rate (tenants) (%)  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                        13.776435                   44.707741
# 4                              NaN                         NaN
# 5                              NaN                         NaN
# 6                              NaN                         NaN
# 7                              NaN                         NaN
# 8                              NaN                         NaN
#
#    Share of activity revenue (%)  Share of retreat pension revenue (%)  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                           67.3                                  30.1
# 4                            NaN                                   NaN
# 5                            NaN                                   NaN
# 6                            NaN                                   NaN
# 7                            NaN                                   NaN
# 8                            NaN                                   NaN
#
#    Share of heritage revenue and other (%)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                     12.8
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
#
#    Share of social benefits revenue (%)  Share of taxes (%)    City name  \
# 0                                   NaN                 NaN       Canari
# 1                                   NaN                 NaN      Chiatra
# 2                                   NaN                 NaN      Chiatra
# 3                                   6.9               -17.1  Ghisonaccia
# 4                                   NaN                 NaN  Montegrosso
# 5                                   NaN                 NaN       Urtaca
# 6                                   NaN                 NaN       Urtaca
# 7                                   NaN                 NaN       Urtaca
# 8                                   NaN                 NaN       Urtaca
#
#   Department  Region custom_arrondissement_code    city_name  \
# 0        2B0      94                      2B002       canari
# 1        2B0      94                      2B003      chiatra
# 2        2B0      94                      2B003      chiatra
# 3        2B0      94                      2B003  ghisonaccia
# 4        2B0      94                      2B005  montegrosso
# 5        2B0      94                      2B005       urtaca
# 6        2B0      94                      2B005       urtaca
# 7        2B0      94                      2B005       urtaca
# 8        2B0      94                      2B005       urtaca
#
#     city_tag_from_food_item
# 0       canari-corse-france
# 1      chiatra-corse-france
# 2      chiatra-corse-france
# 3  ghisonaccia-corse-france
# 4  montegrosso-corse-france
# 5       urtaca-corse-france
# 6       urtaca-corse-france
# 7       urtaca-corse-france
# 8       urtaca-corse-france

# %%
global_arrond.to_csv("../data/processed/clean_food_cities_arrond_with_tax.csv")
